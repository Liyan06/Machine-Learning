# %%
from matplotlib import style
import matplotlib.pyplot as plt
import numpy as np
import mglearn
# %matplotlib inline
style.use("fivethirtyeight")

# %% [markdown]
# # k-neighbors regression

# %% [markdown]
# There is also a regression variant of the k-nearest neighbors algorithm. Again, let’s start by using the single nearest neighbor, this time using the wave dataset. We’ve added three test data points as green stars on the x-axis. The prediction using a single neighbor is just the target value of the nearest neighbor. These are shown as blue stars.

# %%
# Predictions made by one-nearest-neighbor regression on the wave dataset
mglearn.plots.plot_knn_regression(n_neighbors=1)

# %% [markdown]
# When using multiple nearest neighbors, the prediction is the average, or mean, of the relevant neighbors.

# %%
# Predictions made by three-nearest-neighbors regression on the wave dataset
mglearn.plots.plot_knn_regression(n_neighbors=3)

# %% [markdown]
# The k-nearest neighbors algorithm for regression is implemented in the KNeighbors
# Regressor class in scikit-learn. It’s used similarly to KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split

# %%
X, y = mglearn.datasets.make_wave(n_samples=40)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
reg = KNeighborsRegressor(n_neighbors=3)
reg.fit(X_train, y_train)
prediction = reg.predict(X_test)
prediction
# Out:
# array([-0.05396539,  0.35686046,  1.13671923, -1.89415682, -1.13881398,
#        -1.63113382,  0.35686046,  0.91241374, -0.44680446, -1.13881398])

# %%
reg.score(X_test, y_test)
# Out:
# 0.8344172446249604

# %% [markdown]
# We can also evaluate the model using the *score* method, which for regressors returns the R^2^ score. The R^2^ score, also known as the coefficient of determination, is a measure of goodness of a prediction for a regression model, and yields a score between 0 and 1.

# %% [markdown]
# # Analyzing KNeighborsRegressor
